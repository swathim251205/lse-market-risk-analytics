# %%
import pandas as pd

df = pd.read_csv("london_stock_exchange_historical.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2001-07-20  392.255005  392.255005  392.255005  392.255005  275.853577
# 1  2001-07-23  370.760986  393.597992  365.388000  373.984985  263.005219
# 2  2001-07-24  374.523010  374.523010  356.252991  356.790985  250.913574
# 3  2001-07-25  349.268005  350.665009  333.148010  343.894989  241.844330
# 4  2001-07-26  348.192993  348.192993  340.670990  344.968994  242.599701
#
#       Volume
# 0   584009.0
# 1  3205437.0
# 2   790321.0
# 3  1381718.0
# 4  1381718.0

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4425 entries, 0 to 4424
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4425 non-null   object
#  1   Open       4424 non-null   float64
#  2   High       4424 non-null   float64
#  3   Low        4424 non-null   float64
#  4   Close      4424 non-null   float64
#  5   Adj Close  4424 non-null   float64
#  6   Volume     4424 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 242.1+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
import matplotlib.pyplot as plt

df['Close'].plot()
plt.title("LSE Closing Prices Over Time")
plt.show()
